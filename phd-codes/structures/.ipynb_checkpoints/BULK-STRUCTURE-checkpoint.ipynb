# %%
import matplotlib.pyplot as plt
from ase.visualize.plot import plot_atoms
import ase.spacegroup
from ase.visualize import view
from ase.io.cif import read_cif
from ase.io.xyz import write_xyz
from ase.io import read, write
from ase.build import make_supercell
import numpy as np
from ase import Atoms

plt.rcParams['axes.facecolor']= 'none'
plt.rcParams['figure.facecolor'] = 'none'

a =  5.75018200
d = 0.25

atoms=read('GaAs.cif')
atoms.positions *= 1

fig, ax = plt.subplots()
plot_atoms(atoms,
           ax,
           radii=0.4,
           rotation='5x,15y,0z')

plt.show()

# %%
view(atoms,repeat=(1, 1, 4))
# Out:
# <Popen: returncode: None args: ['/home/lflm/anaconda3/envs/ASE/bin/python', ...>

# %%
from gpaw import GPAW
from gpaw import GPAW, PW, FermiDirac

calc = GPAW(mode='lcao',occupations=FermiDirac(0.0, fixmagmom=True),txt='CO.txt')
atoms.calc = calc
e = atoms.get_potential_energy()
calc.write('GaAs.gpw', mode='all')

# %%
calc = GPAW('GaAs.gpw').fixed_density(
    nbands=24,
    symmetry='off',
    convergence={'bands': 8})
# Out:
#   ___ ___ ___ _ _ _
#  |   |   |_  | | | |
#  | | | | | . | | | |
#  |__ |  _|___|_____|  21.1.0
#  |___|_|
#
# User:   lflm@lflm
# Date:   Sat Jun 12 15:31:39 2021
# Arch:   x86_64
# Pid:    104978
# Python: 3.9.4
# gpaw:   /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/gpaw
# _gpaw:  /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/
#         _gpaw.cpython-39-x86_64-linux-gnu.so
# ase:    /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/ase (version 3.21.1)
# numpy:  /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/numpy (version 1.20.3)
# scipy:  /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/scipy (version 1.6.3)
# libxc:  4.3.4
# units:  Angstrom and eV
# cores: 1
# OpenMP: False
# OMP_NUM_THREADS: 1
#
# Input parameters:
#   convergence: {bands: 8}
#   mode: lcao
#   nbands: 24
#   occupations: {name: fermi-dirac,
#                 width: 0.0}
#   symmetry: off
#
# Initialize ...
#
# Ga-setup:
#   name: Gallium
#   id: e1f5b04e536df2d35180d97a9e5d9aca
#   Z: 31.0
#   valence: 3
#   core: 28
#   charge: 0.0
#   file: /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/gpaw/gpaw-setups-0.9.20000/Ga.LDA.gz
#   compensation charges: gauss, rc=0.37, lmax=2
#   cutoffs: 2.06(filt), 4.17(core),
#   valence states:
#                 energy  radius
#     4s(2.00)    -9.167   1.164
#     4p(1.00)    -2.734   1.164
#     *s          18.045   1.164
#     *p          24.478   1.164
#     *d           0.000   1.164
#
#   Using partial waves for Ga as LCAO basis
#
# As-setup:
#   name: Arsenic
#   id: 354e1067b5e66bdeaed68c554076e911
#   Z: 33.0
#   valence: 5
#   core: 28
#   charge: 0.0
#   file: /home/lflm/anaconda3/envs/ASE/lib/python3.9/site-packages/gpaw/gpaw-setups-0.9.20000/As.LDA.gz
#   compensation charges: gauss, rc=0.33, lmax=2
#   cutoffs: 1.87(filt), 2.96(core),
#   valence states:
#                 energy  radius
#     4s(2.00)   -14.691   1.058
#     4p(3.00)    -5.342   1.058
#     *s          12.520   1.058
#     *p          21.869   1.058
#     *d           0.000   1.058
#
#   Using partial waves for As as LCAO basis
#
# Reference energy: -456911.855707
#
# Spin-paired calculation
#
# Convergence criteria:
#   Maximum total energy change: 0.0005 eV / electron
#   Maximum integral of absolute density change: 0.0001 electrons
#   Maximum integral of absolute eigenstate change: 4e-08 eV^2
#   Maximum number of iterations: 333
#
# Symmetries present (total): 1
#
#   ( 1  0  0)
#   ( 0  1  0)
#   ( 0  0  1)
#
# 1 k-point (Gamma)
# 1 k-point in the irreducible part of the Brillouin zone
#        k-points in crystal coordinates                weights
#    0:     0.00000000    0.00000000    0.00000000          1/1
#
# Wave functions: LCAO
#   Diagonalizer: Serial LAPACK
#   Atomic Correction: dense with blas
#   Datatype: float
#
#
# <gpaw.occupations.ZeroWidth object at 0x7f04f804aa90>
# Eigensolver
#    LCAO using direct dense diagonalizer
#
# Densities:
#   Coarse grid: 28*28*28 grid
#   Fine grid: 56*56*56 grid
#   Total Charge: 0.000000
#
# Density mixing:
#   Method: separate
#   Backend: pulay
#   Linear mixing parameter: 0.05
#   Mixing with 5 old densities
#   Damping of long wave oscillations: 50
#
# Hamiltonian:
#   XC and Coulomb potentials evaluated on a 56*56*56 grid
#   Using the LDA Exchange-Correlation functional
#   Interpolation: tri-quintic (5. degree polynomial)
#   Poisson solver: FastPoissonSolver using
#     6*3+1=19 point O(h^6) finite-difference Laplacian stencil;
#     FFT axes: [0, 1, 2];
#     FST axes: [].
#
#
# Memory estimate:
#   Process memory now: 253.70 MiB
#   Calculator: 44.60 MiB
#     Density: 30.97 MiB
#       Arrays: 4.35 MiB
#       Localized functions: 24.94 MiB
#       Mixer: 1.67 MiB
#     Hamiltonian: 4.65 MiB
#       Arrays: 2.85 MiB
#       XC: 0.00 MiB
#       Poisson: 0.00 MiB
#       vbar: 1.80 MiB
#     Wavefunctions: 8.98 MiB
#       C [qnM]: 0.01 MiB
#       S, T [2 x qmm]: 0.02 MiB
#       P [aqMi]: 0.00 MiB
#       BasisFunctions: 8.96 MiB
#       Eigensolver: 0.00 MiB
#
# Total number of cores used: 1
#
# Number of atoms: 8
# Number of atomic orbitals: 32
# Number of bands in calculation: 24
# Number of valence electrons: 32
# Bands to converge: 8
#
# ... initialized
#
# Initializing position-dependent things.
#
#      .-------------.
#     /|             |
#    / |             |
#   /  |  As         |
#  *   |             |
#  |   |       As    |
#  | Ga|         As  |
#  |   .-------------.
#  |  /As Ga        /
#  | /      Ga     /
#  |/             /
#  Ga------------*
#
# Positions:
#    0 Ga     0.000000    0.000000    0.000000    ( 0.0000,  0.0000,  0.0000)
#    1 Ga     0.000000    2.875091    2.875091    ( 0.0000,  0.0000,  0.0000)
#    2 Ga     2.875091    0.000000    2.875091    ( 0.0000,  0.0000,  0.0000)
#    3 Ga     2.875091    2.875091    0.000000    ( 0.0000,  0.0000,  0.0000)
#    4 As     1.437545    1.437545    1.437545    ( 0.0000,  0.0000,  0.0000)
#    5 As     1.437545    4.312636    4.312636    ( 0.0000,  0.0000,  0.0000)
#    6 As     4.312636    1.437545    4.312636    ( 0.0000,  0.0000,  0.0000)
#    7 As     4.312636    4.312636    1.437545    ( 0.0000,  0.0000,  0.0000)
#
# Unit cell:
#            periodic     x           y           z      points  spacing
#   1. axis:    yes    5.750182    0.000000    0.000000    28     0.2054
#   2. axis:    yes    0.000000    5.750182    0.000000    28     0.2054
#   3. axis:    yes    0.000000    0.000000    5.750182    28     0.2054
#
#   Lengths:   5.750182   5.750182   5.750182
#   Angles:   90.000000  90.000000  90.000000
#
# Effective grid spacing dv^(1/3) = 0.2054
#
#                      log10-error:    total        iterations:
#            time      wfs    density  energy       poisson
# iter:   1  15:31:41                 -25.699722    1
# iter:   2  15:31:41                 -25.699722
# iter:   3  15:31:41                 -25.699722
#
# Converged after 3 iterations.
#
# Dipole moment: (-2.360355, -2.360355, -2.360355) |e|*Ang
#
# Energy contributions relative to reference atoms: (reference = -456911.855707)
#
# Kinetic:       +134.445723
# Potential:     -113.583363
# External:        +0.000000
# XC:             -46.619343
# Entropy (-ST):   +0.000000
# Local:           +0.057262
# --------------------------
# Free energy:    -25.699722
# Extrapolated:   -25.699722
#
#  Band  Eigenvalues  Occupancy
#     0     -8.27635    2.00000
#     1     -6.03352    2.00000
#     2     -6.03352    2.00000
#     3     -6.03352    2.00000
#     4     -2.56299    2.00000
#     5     -2.56299    2.00000
#     6     -2.56299    2.00000
#     7      1.68142    2.00000
#     8      1.68142    2.00000
#     9      1.68142    2.00000
#    10      1.68142    2.00000
#    11      1.68142    2.00000
#    12      1.68142    2.00000
#    13      4.07414    2.00000
#    14      4.18640    2.00000
#    15      4.18640    2.00000
#    16      4.18640    0.00000
#    17      6.57939    0.00000
#    18      6.57939    0.00000
#    19      6.57939    0.00000
#    20      7.18476    0.00000
#    21      7.18476    0.00000
#    22      7.18476    0.00000
#    23      8.33968    0.00000
#
# Fermi level: 4.18640
#
# Gap: 2.393 eV
# Transition (v -> c):
#   (s=0, k=0, n=16, [0.00, 0.00, 0.00]) -> (s=0, k=0, n=17, [0.00, 0.00, 0.00])

# %%
gaas = calc.band_structure()
gaas
# Out:
# BandStructure(path=BandPath(path='GG', cell=[3x3], special_points={GMRX}, kpts=[1x3]), energies=[1x1x24 values], reference=4.186399369253231)
