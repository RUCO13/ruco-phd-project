# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,6*np.pi,0.1)

for  i in range(0,16,):
    if i < 8:
        plt.plot(x,i*0.2*np.sin(x))
    else:
        plt.plot(x,-i*0.2*np.sin(x))
